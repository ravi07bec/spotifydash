# %%
# !python app_final.py
# Out:
# [{'label': ' Eric Clapton', 'value': ' Eric Clapton'}, {'label': ' Jul', 'value': ' Jul'}, {'label': ' Marco Antonio Solís', 'value': ' Marco Antonio Solís'}, {'label': ' Mitiska & Jaren', 'value': ' Mitiska & Jaren'}, {'label': ' Mon Laferte', 'value': ' Mon Laferte'}, {'label': ' Ninho', 'value': ' Ninho'}, {'label': ' Phil Collins', 'value': ' Phil Collins'}, {'label': ' Sean Paul', 'value': ' Sean Paul'}, {'label': ' T.I.', 'value': ' T.I.'}, {'label': ' The Creator', 'value': ' The Creator'}, {'label': ' Wisin', 'value': ' Wisin'}, {'label': '2 Chainz', 'value': '2 Chainz'}, {'label': '21 Savage', 'value': '21 Savage'}, {'label': '2Pac', 'value': '2Pac'}, {'label': '5 Seconds of Summer', 'value': '5 Seconds of Summer'}, {'label': '50 Cent', 'value': '50 Cent'}, {'label': '6ix9ine', 'value': '6ix9ine'}, {'label': 'A Boogie Wit da Hoodie', 'value': 'A Boogie Wit da Hoodie'}, {'label': 'A$AP Rocky', 'value': 'A$AP Rocky'}, {'label': 'A.R. Rahman', 'value': 'A.R. Rahman'}, {'label':
# ...

# %%
# !pip install dash
# Out:
# ...
#      |████████████████████████████████| 1.1 MB 7.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.7 MB 59.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 83 kB 4.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 1.8 MB 83.9 MB/s eta 0:00:01
# ...
#   Created wheel for dash: filename=dash-1.21.0-py3-none-any.whl size=1100477 sha256=de03d3db6a778145e4bec0751d20dd0a1b79df7980e36a25ead9c976aa88e7c2
#   Stored in directory: /local/home/rvshnkr/.cache/pip/wheels/59/a4/f1/a7140afcad8dbaa3b1b12ef80843d29403d6ecca1c2f397948
# ...
#   Created wheel for dash-core-components: filename=dash_core_components-1.17.1-py3-none-any.whl size=3738982 sha256=653de704375a5c6e54bd412c4bc773de14aff8f5c6766f652de48d9abeac9f15
#   Stored in directory: /local/home/rvshnkr/.cache/pip/wheels/ca/5b/fb/a135a7bf8e21223e4104aa5526a5173a20b64fe7fcd055b999
# ...
